# %%
#-------Ao final do processamento, o valor da variável SOMA será 91 -----------
INDICE = int(13)
SOMA = 0
K = 0

while K < INDICE:
  K = K + 1
  SOMA = SOMA + K
  print(SOMA)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
