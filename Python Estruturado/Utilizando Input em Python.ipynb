# %%
nome = input('Digite o nome: ')
idade = int(input('Digite a idade: '))
peso = float(input('Digite o peso: '))
print('Me chamo {}, tenho {} anos de idade, e peso {}Kg'.format(nome, idade, peso))
print(f'Me chamo {nome}, tenho {idade} anos de idade, e peso {peso}Kg')
# Out:
# Digite o nome: David
# Digite a idade: 22
# Digite o peso: 70
# Me chamo David, tenho 22 anos de idade, e peso 70.0Kg
# Me chamo David, tenho 22 anos de idade, e peso 70.0Kg

# %%
nome = input('Qual é o seu nome ?: ')
print(f'Olá {nome}!  Seja bem vindo(a) ao nosso programa!')
# Out:
# Qual é o seu nome ?: David
# Olá David! Seja bem vindo(a) ao nosso programa!

# %%
dia = int(input('Informe seu dia de nascimento: '))
mes = int(input('Informe seu mês de nascimento: '))
ano = int(input('Informe seu ano de nascimento: '))
print(f'Sua data de nascimento é: {dia}/{mes}/{ano}')
# Out:
# Informe seu dia de nascimento: 13
# Informe seu mês de nascimento: 07
# Informe seu ano de nascimento: 2002
# Sua data de nascimento é: 13/7/2002

# %%
n1 = float(input('Digite o um numero: '))
n2 = float(input('Digite outro numero: '))
r1 = (n1 + n2)
print(f'A soma de {n1} + {n2} = {r1}')
# Out:
# Digite o um numero: 2
# Digite outro numero: 5
# A soma de 2.0 + 5.0 = 7.0
