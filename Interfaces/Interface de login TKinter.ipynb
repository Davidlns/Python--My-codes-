# %%
# !pip install customtkinter
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.1/296.1 kB 5.1 MB/s eta 0:00:00
# ...

# %%
from customtkinter import *

def clickbt ():
    print("VOCÊ FEZ LOGIN COM SUCESSO!!")
def custonlog ():

    paglog = CTk()
    paglog.title("CYBLOG")
    paglog.geometry("700x500")

    CTkLabel(paglog, text = "Fazer Login").pack(padx = 10, pady = 10)

    CTkLabel(paglog, text = "Usuário:").pack(padx = 10, pady = 10)
    usu = CTkEntry(paglog).pack()

    CTkLabel(paglog, text="Senha:").pack(padx=10, pady=10)
    senha = CTkEntry(paglog).pack()

    lemb = CTkCheckBox(paglog, text = "Lembrar").pack(padx = 15, pady = 15)

    btlog = CTkButton(paglog, text = "Login", command= clickbt).pack(padx = 10, pady = 10)







    paglog.mainloop()

print(custonlog())
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-6-dfca1b5516b9> in <cell line: 31>()
#      29     paglog.mainloop()
#      30
# ---> 31 print(custonlog())
#
# <ipython-input-6-dfca1b5516b9> in custonlog()
#       5 def custonlog ():
#       6
# ----> 7     paglog = CTk()
#       8     paglog.title("CYBLOG")
#       9     paglog.geometry("700x500")
#
# /usr/local/lib/python3.10/dist-packages/customtkinter/windows/ctk_tk.py in __init__(self, fg_color, **kwargs)
#      38
#      39         # call init methods of super classes
# ---> 40         CTK_PARENT_CLASS.__init__(self, **pop_from_dict_by_set(kwargs, self._valid_tk_constructor_arguments))
#      41         CTkAppearanceModeBaseClass.__init__(self)
#      42         CTkScalingBaseClass.__init__(self, scaling_type="window")
#
# ...
